# %% [markdown]
# <!-- 2) Viết chương trình nạp 1 ảnh và hoán đổi giá trị các màu. -->

# %%
import numpy as np
import imageio.v2 as iio
import matplotlib.pylab as plt
data = iio.imread('dog.png')
bdata = (data[:,:,2] + data[:,:,0])
plt.imshow(bdata)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
