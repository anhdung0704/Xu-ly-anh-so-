# %% [markdown]
# <!-- 1) Viết chương trình nạp 1 ảnh và lưu thành 3 ảnh 3 màu khác nhau. -->

# %%
from PIL import Image
import numpy as np
img = Image.open("dog.png")
img.show()

# %%
import numpy as np
import imageio.v2 as iio
import matplotlib.pylab as plt
from skimage import io
data = io.imread('dog.png', as_gray = True)
plt.imshow(data,cmap='gray')
plt.show()

# %%
import numpy as np
import imageio.v2 as iio
import matplotlib.pylab as plt
data = iio.imread('dog.png')
bdata = (data[:,:,1] + data[:,:,2])
plt.imshow(bdata)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import imageio.v2 as iio
import matplotlib.pylab as plt
data = iio.imread("dog.png")
plt.imshow(data)
plt.show()
