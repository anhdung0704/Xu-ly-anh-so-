# %% [markdown]
# <!-- 3) VIết chương trình nạp 1 ảnh , chuyển thành hệ màu HSV và lưu 3 ảnh 3 màu khác nhau -->

# %%
import numpy as np 
import imageio.v2 as iio
import matplotlib.pylab as plt
import colorsys

rgb = iio.imread('dog.png')
rgb2hsv = np.vectorize (colorsys.rgb_to_hsv)
h ,s ,v = rgb2hsv(rgb[:,:,0], rgb[:,:,1], rgb[:,:,2])
h *= h
hsv2rgb = np.vectorize (colorsys.hls_to_rgb)
rgb2 = hsv2rgb(h,s,v)
rgb2 = np.array(rgb2).transpose((1,2,0))
plt.imshow(rgb2)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-123.50399999999999..124.496].

# %%
import numpy as np 
import imageio.v2 as iio
import matplotlib.pylab as plt
import colorsys

rgb = iio.imread('dog.png')
rgb2hsv = np.vectorize (colorsys.rgb_to_hsv)
h ,s ,v = rgb2hsv(rgb[:,:,1], rgb[:,:,2], rgb[:,:,0])
h *= h
hsv2rgb = np.vectorize (colorsys.hls_to_rgb)
rgb2 = hsv2rgb(h,s,v)
rgb2 = np.array(rgb2).transpose((1,2,0))
plt.imshow(rgb2)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-123.50399999999999..124.496].

# %%
import numpy as np 
import imageio.v2 as iio
import matplotlib.pylab as plt
import colorsys

rgb = iio.imread('dog.png')
rgb2hsv = np.vectorize (colorsys.rgb_to_hsv)
h ,s ,v = rgb2hsv(rgb[:,:,2], rgb[:,:,0], rgb[:,:,1])
h *= h
hsv2rgb = np.vectorize (colorsys.hls_to_rgb)
rgb2 = hsv2rgb(h,s,v)
rgb2 = np.array(rgb2).transpose((1,2,0))
plt.imshow(rgb2)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-123.50399999999999..124.496].
